# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
citipy
# Out:
# <module 'citipy.citipy' from 'c:\\Users\\jeff\\.conda\\envs\\dev\\lib\\site-packages\\citipy\\citipy.py'>

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds =  city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | blackmans bay
# Processing Record 3 of Set 1 | illizi
# Processing Record 4 of Set 1 | puerto natales
# Processing Record 5 of Set 1 | klyuchi
# Processing Record 6 of Set 1 | gardez
# Processing Record 7 of Set 1 | west island
# Processing Record 8 of Set 1 | iowa park
# Processing Record 9 of Set 1 | colonia
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | mazagao
# Processing Record 13 of Set 1 | chiili
# City not found. Skipping...
# Processing Record 14 of Set 1 | tera
# Processing Record 15 of Set 1 | uliastay
# Processing Record 16 of Set 1 | vorgashor
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | dauphin
# Processing Record 20 of Set 1 | sanming
# Processing Record 21 of Set 1 | ust-nera
# Processing Record 22 of Set 1 | port moresby
# Processing Record 23 of Set 1 | khilok
# Processing Record 24 of Set 1 | vernon
# Processing Record 25 of Set 1 | belozersk
# Processing Record 26 of Set 1 | vadso
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | abdulino
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | laojunmiao
# Processing Record 31 of Set 1 | tura
# Processing Record 32 of Set 1 | kapa'a
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | ust'-ilimsk
# Processing Record 35 of Set 1 | ipilan
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | wailua homesteads
# Processing Record 38 of Set 1 | oqtosh
# Processing Record 39 of Set 1 | olonkinbyen
# Processing Record 40 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 1 | edinburgh of the seven seas
# Processing Record 42 of Set 1 | haiku-pauwela
# Processing Record 43 of Set 1 | egilsstadir
# Processing Record 44 of Set 1 | poronaysk
# Processing Record 45 of Set 1 | midvagur
# Processing Record 46 of Set 1 | la passe
# Processing Record 47 of Set 1 | stanley
# Processing Record 48 of Set 1 | la palma
# Processing Record 49 of Set 1 | hammerfest
# Processing Record 50 of Set 1 | adamstown
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | tofol
# Processing Record 3 of Set 2 | quthbullapur
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | nuku'alofa
# Processing Record 6 of Set 2 | siavonga
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | pocone
# Processing Record 10 of Set 2 | whitehorse
# Processing Record 11 of Set 2 | kampong thom
# Processing Record 12 of Set 2 | papatowai
# Processing Record 13 of Set 2 | hawaiian paradise park
# Processing Record 14 of Set 2 | mossel bay
# Processing Record 15 of Set 2 | tindouf
# Processing Record 16 of Set 2 | nikol'sk
# Processing Record 17 of Set 2 | quellon
# Processing Record 18 of Set 2 | gadzhiyevo
# Processing Record 19 of Set 2 | jawhar
# Processing Record 20 of Set 2 | sinabang
# Processing Record 21 of Set 2 | amahai
# Processing Record 22 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 23 of Set 2 | freetown
# Processing Record 24 of Set 2 | alice springs
# Processing Record 25 of Set 2 | invercargill
# Processing Record 26 of Set 2 | mirny
# Processing Record 27 of Set 2 | margaret river
# Processing Record 28 of Set 2 | mount pearl
# Processing Record 29 of Set 2 | afaahiti
# Processing Record 30 of Set 2 | lagoa
# Processing Record 31 of Set 2 | bulungu
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | ingeniero guillermo n. juarez
# Processing Record 34 of Set 2 | porto novo
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | tarariras
# Processing Record 37 of Set 2 | utrik
# Processing Record 38 of Set 2 | bethanie
# Processing Record 39 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 2 | buka
# Processing Record 41 of Set 2 | gislaved
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | gandi
# Processing Record 44 of Set 2 | bilibino
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | saipan
# Processing Record 47 of Set 2 | queenstown
# Processing Record 48 of Set 2 | tralee
# Processing Record 49 of Set 2 | la'ie
# Processing Record 0 of Set 3 | badger
# Processing Record 1 of Set 3 | iskateley
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | mansa
# Processing Record 4 of Set 3 | pionerskiy
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | nadym
# Processing Record 7 of Set 3 | oranjemund
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | lompoc
# Processing Record 10 of Set 3 | jardim
# Processing Record 11 of Set 3 | codrington
# Processing Record 12 of Set 3 | suntar
# Processing Record 13 of Set 3 | al kharijah
# Processing Record 14 of Set 3 | gaigeturi
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | leiyang
# Processing Record 17 of Set 3 | san juan
# Processing Record 18 of Set 3 | blackfoot
# Processing Record 19 of Set 3 | ephraim
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 3 | mellouleche
# Processing Record 23 of Set 3 | malinyi
# Processing Record 24 of Set 3 | ulladulla
# Processing Record 25 of Set 3 | fisterra
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | paracale
# Processing Record 28 of Set 3 | christchurch
# Processing Record 29 of Set 3 | saint-pierre
# Processing Record 30 of Set 3 | homer
# Processing Record 31 of Set 3 | remire-montjoly
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | bubaque
# Processing Record 34 of Set 3 | san andres
# Processing Record 35 of Set 3 | kenai
# Processing Record 36 of Set 3 | saratoga springs
# Processing Record 37 of Set 3 | vilyuchinsk
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | jinhua
# Processing Record 40 of Set 3 | pemba
# Processing Record 41 of Set 3 | arkhangel'sk
# Processing Record 42 of Set 3 | lihue
# Processing Record 43 of Set 3 | natal
# Processing Record 44 of Set 3 | howard springs
# Processing Record 45 of Set 3 | fonadhoo
# City not found. Skipping...
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | ancud
# Processing Record 48 of Set 3 | holualoa
# Processing Record 49 of Set 3 | hamilton
# Processing Record 0 of Set 4 | petone
# Processing Record 1 of Set 4 | zhanga buqtyrma
# Processing Record 2 of Set 4 | balaipungut
# Processing Record 3 of Set 4 | san jose de guanipa
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | fale old settlement
# Processing Record 6 of Set 4 | edd
# Processing Record 7 of Set 4 | moab
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | udachny
# Processing Record 10 of Set 4 | shimoda
# Processing Record 11 of Set 4 | waddan
# Processing Record 12 of Set 4 | dudinka
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | contamana
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | callao
# Processing Record 17 of Set 4 | chonchi
# Processing Record 18 of Set 4 | ishigaki
# Processing Record 19 of Set 4 | namibe
# Processing Record 20 of Set 4 | sosnovo-ozerskoye
# Processing Record 21 of Set 4 | vila franca do campo
# Processing Record 22 of Set 4 | st. john's
# Processing Record 23 of Set 4 | idah
# Processing Record 24 of Set 4 | selfoss
# Processing Record 25 of Set 4 | bardai
# Processing Record 26 of Set 4 | sisimiut
# Processing Record 27 of Set 4 | bindura
# Processing Record 28 of Set 4 | atafu village
# Processing Record 29 of Set 4 | keflavik
# Processing Record 30 of Set 4 | goz beida
# Processing Record 31 of Set 4 | diamantino
# Processing Record 32 of Set 4 | broken hill
# Processing Record 33 of Set 4 | pyoksong-up
# Processing Record 34 of Set 4 | charkhi dadri
# Processing Record 35 of Set 4 | inhambane
# Processing Record 36 of Set 4 | kailua-kona
# Processing Record 37 of Set 4 | qurayyat
# Processing Record 38 of Set 4 | ponta delgada
# Processing Record 39 of Set 4 | bekalta
# Processing Record 40 of Set 4 | slobozhans'ke
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | hotan
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | tarawa
# Processing Record 46 of Set 4 | praia da vitoria
# Processing Record 47 of Set 4 | marsabit
# Processing Record 48 of Set 4 | sosnogorsk
# Processing Record 49 of Set 4 | sao gabriel
# Processing Record 0 of Set 5 | leshan
# Processing Record 1 of Set 5 | rio grande
# Processing Record 2 of Set 5 | susuman
# Processing Record 3 of Set 5 | georgetown
# Processing Record 4 of Set 5 | xichang
# Processing Record 5 of Set 5 | pante makasar
# City not found. Skipping...
# Processing Record 6 of Set 5 | prabumulih
# Processing Record 7 of Set 5 | iqaluit
# Processing Record 8 of Set 5 | ust-tsilma
# Processing Record 9 of Set 5 | champerico
# Processing Record 10 of Set 5 | hithadhoo
# Processing Record 11 of Set 5 | tommot
# Processing Record 12 of Set 5 | kinablangan
# Processing Record 13 of Set 5 | calingasta
# Processing Record 14 of Set 5 | palikir - national government center
# Processing Record 15 of Set 5 | serhetabat
# Processing Record 16 of Set 5 | jamestown
# Processing Record 17 of Set 5 | hadibu
# Processing Record 18 of Set 5 | tamanrasset
# Processing Record 19 of Set 5 | gaiman
# Processing Record 20 of Set 5 | aasiaat
# Processing Record 21 of Set 5 | bhavnagar
# Processing Record 22 of Set 5 | aberdeen
# Processing Record 23 of Set 5 | tal'menka
# Processing Record 24 of Set 5 | thunder bay
# Processing Record 25 of Set 5 | concordia
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | nyurba
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | gumdag
# Processing Record 30 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 31 of Set 5 | okhotsk
# Processing Record 32 of Set 5 | hinton
# Processing Record 33 of Set 5 | quelimane
# Processing Record 34 of Set 5 | kangding
# Processing Record 35 of Set 5 | castillos
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | mahibadhoo
# Processing Record 38 of Set 5 | qaqortoq
# Processing Record 39 of Set 5 | malpe
# Processing Record 40 of Set 5 | bilao
# Processing Record 41 of Set 5 | itaituba
# Processing Record 42 of Set 5 | gulu
# Processing Record 43 of Set 5 | paita
# Processing Record 44 of Set 5 | zyryanskoye
# Processing Record 45 of Set 5 | qarauyl
# Processing Record 46 of Set 5 | kyshtovka
# Processing Record 47 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 48 of Set 5 | santa ana
# Processing Record 49 of Set 5 | baraolt
# Processing Record 0 of Set 6 | puerto baquerizo moreno
# Processing Record 1 of Set 6 | sao tome
# Processing Record 2 of Set 6 | arteche
# Processing Record 3 of Set 6 | tazovsky
# Processing Record 4 of Set 6 | abasolo
# Processing Record 5 of Set 6 | as sulayyil
# Processing Record 6 of Set 6 | wynyard
# Processing Record 7 of Set 6 | nemuro
# Processing Record 8 of Set 6 | achit
# Processing Record 9 of Set 6 | balabac
# Processing Record 10 of Set 6 | kimbe
# Processing Record 11 of Set 6 | vizinga
# Processing Record 12 of Set 6 | isafjordur
# Processing Record 13 of Set 6 | tazacorte
# Processing Record 14 of Set 6 | pimenta bueno
# Processing Record 15 of Set 6 | martuk
# Processing Record 16 of Set 6 | betio village
# Processing Record 17 of Set 6 | awka
# Processing Record 18 of Set 6 | marica
# Processing Record 19 of Set 6 | dwarka
# Processing Record 20 of Set 6 | owen sound
# Processing Record 21 of Set 6 | kokologo
# Processing Record 22 of Set 6 | cururupu
# Processing Record 23 of Set 6 | mbanza kongo
# Processing Record 24 of Set 6 | kingston
# Processing Record 25 of Set 6 | we
# City not found. Skipping...
# Processing Record 26 of Set 6 | kiunga
# Processing Record 27 of Set 6 | avarua
# Processing Record 28 of Set 6 | faya-largeau
# Processing Record 29 of Set 6 | brezina
# Processing Record 30 of Set 6 | las palmas
# Processing Record 31 of Set 6 | dubti
# Processing Record 32 of Set 6 | jaru
# Processing Record 33 of Set 6 | fortuna
# Processing Record 34 of Set 6 | ketchikan
# Processing Record 35 of Set 6 | lavrio
# Processing Record 36 of Set 6 | sabang
# Processing Record 37 of Set 6 | ishikawa
# Processing Record 38 of Set 6 | beykonak
# Processing Record 39 of Set 6 | karatuzskoye
# Processing Record 40 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 41 of Set 6 | gueret
# Processing Record 42 of Set 6 | crane
# Processing Record 43 of Set 6 | bonga
# Processing Record 44 of Set 6 | west helena
# Processing Record 45 of Set 6 | masuguru
# Processing Record 46 of Set 6 | papao
# Processing Record 47 of Set 6 | altai
# Processing Record 48 of Set 6 | kerikeri
# Processing Record 49 of Set 6 | moroni
# Processing Record 0 of Set 7 | fort bragg
# Processing Record 1 of Set 7 | kavaratti
# Processing Record 2 of Set 7 | basco
# Processing Record 3 of Set 7 | srivardhan
# Processing Record 4 of Set 7 | rabo de peixe
# Processing Record 5 of Set 7 | springs
# Processing Record 6 of Set 7 | zhicheng
# Processing Record 7 of Set 7 | westport
# Processing Record 8 of Set 7 | tlaltenango de sanchez roman
# Processing Record 9 of Set 7 | idrinskoye
# Processing Record 10 of Set 7 | new norfolk
# Processing Record 11 of Set 7 | igarka
# Processing Record 12 of Set 7 | zhaotong
# Processing Record 13 of Set 7 | turpan
# Processing Record 14 of Set 7 | banda aceh
# Processing Record 15 of Set 7 | trevelin
# Processing Record 16 of Set 7 | constantia
# Processing Record 17 of Set 7 | yaren
# Processing Record 18 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 7 | olbia
# Processing Record 20 of Set 7 | mancio lima
# Processing Record 21 of Set 7 | coquimbo
# Processing Record 22 of Set 7 | port alfred
# Processing Record 23 of Set 7 | al ghayzah
# Processing Record 24 of Set 7 | weno
# Processing Record 25 of Set 7 | pisco
# Processing Record 26 of Set 7 | yuzhno-kurilsk
# Processing Record 27 of Set 7 | ambovombe
# Processing Record 28 of Set 7 | patnos
# Processing Record 29 of Set 7 | toro
# Processing Record 30 of Set 7 | tanout
# Processing Record 31 of Set 7 | yambio
# Processing Record 32 of Set 7 | san antonio de pale
# Processing Record 33 of Set 7 | manay
# Processing Record 34 of Set 7 | boguchany
# Processing Record 35 of Set 7 | yarmouth
# Processing Record 36 of Set 7 | kavieng
# Processing Record 37 of Set 7 | necochea
# Processing Record 38 of Set 7 | amilly
# Processing Record 39 of Set 7 | hami
# Processing Record 40 of Set 7 | rikaze
# Processing Record 41 of Set 7 | happy valley-goose bay
# Processing Record 42 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 43 of Set 7 | inirida
# Processing Record 44 of Set 7 | ivins
# Processing Record 45 of Set 7 | estherville
# Processing Record 46 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 7 | isle of arran
# City not found. Skipping...
# Processing Record 48 of Set 7 | palmer
# Processing Record 49 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 0 of Set 8 | arfoud
# Processing Record 1 of Set 8 | uturoa
# Processing Record 2 of Set 8 | la carlota
# Processing Record 3 of Set 8 | new plymouth
# Processing Record 4 of Set 8 | nola
# Processing Record 5 of Set 8 | lockport
# Processing Record 6 of Set 8 | umm kaddadah
# Processing Record 7 of Set 8 | chirchiq
# Processing Record 8 of Set 8 | bairnsdale
# Processing Record 9 of Set 8 | luang namtha
# Processing Record 10 of Set 8 | vila do maio
# Processing Record 11 of Set 8 | reggane
# Processing Record 12 of Set 8 | wad rawah
# Processing Record 13 of Set 8 | hilo
# Processing Record 14 of Set 8 | pamandzi
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | vallenar
# Processing Record 17 of Set 8 | irondequoit
# Processing Record 18 of Set 8 | brokopondo
# Processing Record 19 of Set 8 | nushki
# Processing Record 20 of Set 8 | soria
# Processing Record 21 of Set 8 | lospalos
# Processing Record 22 of Set 8 | kudahuvadhoo
# Processing Record 23 of Set 8 | kamaishi
# Processing Record 24 of Set 8 | la mira
# Processing Record 25 of Set 8 | flin flon
# Processing Record 26 of Set 8 | cabo san lucas
# Processing Record 27 of Set 8 | ambon
# Processing Record 28 of Set 8 | trenggalek
# Processing Record 29 of Set 8 | orapa
# Processing Record 30 of Set 8 | marsa alam
# Processing Record 31 of Set 8 | nefta
# Processing Record 32 of Set 8 | san felipe
# Processing Record 33 of Set 8 | taunsa
# Processing Record 34 of Set 8 | east ballina
# Processing Record 35 of Set 8 | port mathurin
# Processing Record 36 of Set 8 | scarborough
# Processing Record 37 of Set 8 | wa
# City not found. Skipping...
# Processing Record 38 of Set 8 | balikpapan
# Processing Record 39 of Set 8 | opuwo
# Processing Record 40 of Set 8 | argo
# Processing Record 41 of Set 8 | yabelo
# Processing Record 42 of Set 8 | ciudad del carmen
# Processing Record 43 of Set 8 | karakecili
# Processing Record 44 of Set 8 | kruisfontein
# Processing Record 45 of Set 8 | magong
# Processing Record 46 of Set 8 | melilla
# Processing Record 47 of Set 8 | tucuma
# Processing Record 48 of Set 8 | prince george
# Processing Record 49 of Set 8 | danville
# Processing Record 0 of Set 9 | jolo
# Processing Record 1 of Set 9 | mazamari
# Processing Record 2 of Set 9 | taulaga
# Processing Record 3 of Set 9 | chelsea
# Processing Record 4 of Set 9 | tabuk
# Processing Record 5 of Set 9 | gisborne
# Processing Record 6 of Set 9 | kovernino
# Processing Record 7 of Set 9 | mahina
# Processing Record 8 of Set 9 | huntsville
# Processing Record 9 of Set 9 | aykhal
# Processing Record 10 of Set 9 | kiama
# Processing Record 11 of Set 9 | san luis
# Processing Record 12 of Set 9 | xuanzhou
# Processing Record 13 of Set 9 | behshahr
# Processing Record 14 of Set 9 | atar
# Processing Record 15 of Set 9 | brisas de zicatela
# Processing Record 16 of Set 9 | sarupathar
# Processing Record 17 of Set 9 | maceio
# Processing Record 18 of Set 9 | chivhu
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | key west
# Processing Record 21 of Set 9 | taoudenni
# Processing Record 22 of Set 9 | jumla
# Processing Record 23 of Set 9 | lorengau
# Processing Record 24 of Set 9 | tanjung selor
# City not found. Skipping...
# Processing Record 25 of Set 9 | novodvinsk
# Processing Record 26 of Set 9 | tamiahua
# Processing Record 27 of Set 9 | gobabis
# Processing Record 28 of Set 9 | walvis bay
# Processing Record 29 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 30 of Set 9 | tromso
# Processing Record 31 of Set 9 | san julian
# Processing Record 32 of Set 9 | liwale
# Processing Record 33 of Set 9 | batala
# Processing Record 34 of Set 9 | luderitz
# Processing Record 35 of Set 9 | kande
# Processing Record 36 of Set 9 | patterson
# Processing Record 37 of Set 9 | enewetak
# Processing Record 38 of Set 9 | nar'yan-mar
# Processing Record 39 of Set 9 | cimislia
# Processing Record 40 of Set 9 | gualeguay
# Processing Record 41 of Set 9 | guerrero negro
# Processing Record 42 of Set 9 | childress
# Processing Record 43 of Set 9 | cedeira
# Processing Record 44 of Set 9 | xianning
# Processing Record 45 of Set 9 | corner brook
# Processing Record 46 of Set 9 | imphal
# Processing Record 47 of Set 9 | puerto aysen
# Processing Record 48 of Set 9 | senanga
# Processing Record 49 of Set 9 | flying fish cove
# Processing Record 0 of Set 10 | miracatu
# Processing Record 1 of Set 10 | la rinconada
# Processing Record 2 of Set 10 | renk
# City not found. Skipping...
# Processing Record 3 of Set 10 | salalah
# Processing Record 4 of Set 10 | maloye ganyushkino
# Processing Record 5 of Set 10 | labrador city
# Processing Record 6 of Set 10 | calabozo
# Processing Record 7 of Set 10 | chardara
# Processing Record 8 of Set 10 | kanniyakumari
# Processing Record 9 of Set 10 | pacific grove
# Processing Record 10 of Set 10 | port augusta
# Processing Record 11 of Set 10 | paphos
# Processing Record 12 of Set 10 | heihe
# Processing Record 13 of Set 10 | bouca
# Processing Record 14 of Set 10 | tuy hoa
# Processing Record 15 of Set 10 | zouerate
# Processing Record 16 of Set 10 | aketi
# Processing Record 17 of Set 10 | smithers
# Processing Record 18 of Set 10 | dunedin
# Processing Record 19 of Set 10 | seeb
# Processing Record 20 of Set 10 | santana
# Processing Record 21 of Set 10 | sao joao da barra
# Processing Record 22 of Set 10 | kone
# Processing Record 23 of Set 10 | black point
# Processing Record 24 of Set 10 | newnham
# Processing Record 25 of Set 10 | eirunepe
# Processing Record 26 of Set 10 | zdvinsk
# Processing Record 27 of Set 10 | idri
# Processing Record 28 of Set 10 | mumbwa
# Processing Record 29 of Set 10 | albertina
# Processing Record 30 of Set 10 | amreli
# Processing Record 31 of Set 10 | howrah
# Processing Record 32 of Set 10 | kirensk
# Processing Record 33 of Set 10 | antofagasta
# Processing Record 34 of Set 10 | namanyere
# Processing Record 35 of Set 10 | neftcala
# Processing Record 36 of Set 10 | elko
# Processing Record 37 of Set 10 | acapulco de juarez
# Processing Record 38 of Set 10 | nikolayevsk-on-amure
# Processing Record 39 of Set 10 | callaway
# Processing Record 40 of Set 10 | kununurra
# Processing Record 41 of Set 10 | khandyga
# Processing Record 42 of Set 10 | vanino
# Processing Record 43 of Set 10 | mlangali
# Processing Record 44 of Set 10 | djambala
# Processing Record 45 of Set 10 | dalbandin
# Processing Record 46 of Set 10 | laguna
# Processing Record 47 of Set 10 | santo antonio do taua
# Processing Record 48 of Set 10 | bikenibeu village
# Processing Record 49 of Set 10 | nsanje
# Processing Record 0 of Set 11 | tolanaro
# Processing Record 1 of Set 11 | mahmutlar
# Processing Record 2 of Set 11 | porkhov
# Processing Record 3 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 4 of Set 11 | lao cai
# Processing Record 5 of Set 11 | monduli
# Processing Record 6 of Set 11 | al bawiti
# Processing Record 7 of Set 11 | forster
# Processing Record 8 of Set 11 | yugorsk
# Processing Record 9 of Set 11 | lazaro cardenas
# Processing Record 10 of Set 11 | muisne
# Processing Record 11 of Set 11 | kingsford
# Processing Record 12 of Set 11 | awjilah
# Processing Record 13 of Set 11 | okha
# Processing Record 14 of Set 11 | meadow lake
# Processing Record 15 of Set 11 | tahoua
# Processing Record 16 of Set 11 | roma
# Processing Record 17 of Set 11 | goundam
# Processing Record 18 of Set 11 | kudymkar
# Processing Record 19 of Set 11 | talara
# Processing Record 20 of Set 11 | toppenish
# Processing Record 21 of Set 11 | siwa oasis
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | kapuskasing
# Processing Record 24 of Set 11 | kosan
# Processing Record 25 of Set 11 | saint-georges
# Processing Record 26 of Set 11 | gamay
# Processing Record 27 of Set 11 | dazhou
# Processing Record 28 of Set 11 | shangri-la
# City not found. Skipping...
# Processing Record 29 of Set 11 | 'ain benian
# Processing Record 30 of Set 11 | mozarlandia
# Processing Record 31 of Set 11 | lewistown
# Processing Record 32 of Set 11 | clinton
# Processing Record 33 of Set 11 | sogndal
# Processing Record 34 of Set 11 | tumpat
# Processing Record 35 of Set 11 | tosham
# Processing Record 36 of Set 11 | aleg
# Processing Record 37 of Set 11 | floro
# Processing Record 38 of Set 11 | bidar
# Processing Record 39 of Set 11 | mammoth lakes
# Processing Record 40 of Set 11 | espinosa
# Processing Record 41 of Set 11 | kodumudi
# Processing Record 42 of Set 11 | esmeraldas
# Processing Record 43 of Set 11 | sadjoavato
# City not found. Skipping...
# Processing Record 44 of Set 11 | bengkulu
# Processing Record 45 of Set 11 | markovo
# Processing Record 46 of Set 11 | birao
# Processing Record 47 of Set 11 | taltal
# Processing Record 48 of Set 11 | baiyin
# Processing Record 49 of Set 11 | binkolo
# Processing Record 0 of Set 12 | ivdel'
# Processing Record 1 of Set 12 | thai nguyen
# Processing Record 2 of Set 12 | solnechnyy
# Processing Record 3 of Set 12 | veraval
# Processing Record 4 of Set 12 | al qadarif
# Processing Record 5 of Set 12 | richards bay
# Processing Record 6 of Set 12 | shiqian
# Processing Record 7 of Set 12 | naxos
# Processing Record 8 of Set 12 | crucecita
# Processing Record 9 of Set 12 | bac lieu
# Processing Record 10 of Set 12 | mejit
# Processing Record 11 of Set 12 | amga
# Processing Record 12 of Set 12 | ocean shores
# Processing Record 13 of Set 12 | hirara
# Processing Record 14 of Set 12 | kibaya
# Processing Record 15 of Set 12 | bukama
# Processing Record 16 of Set 12 | antsiranana
# Processing Record 17 of Set 12 | takum
# Processing Record 18 of Set 12 | parham
# Processing Record 19 of Set 12 | aioun
# Processing Record 20 of Set 12 | gueltat zemmour
# City not found. Skipping...
# Processing Record 21 of Set 12 | chinde
# Processing Record 22 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 12 | naze
# Processing Record 24 of Set 12 | laayoune plage
# City not found. Skipping...
# Processing Record 25 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 26 of Set 12 | mili
# Processing Record 27 of Set 12 | coahuayana de hidalgo
# Processing Record 28 of Set 12 | lethem
# Processing Record 29 of Set 12 | neya
# Processing Record 30 of Set 12 | santa cruz
# Processing Record 31 of Set 12 | guangming
# Processing Record 32 of Set 12 | caleta de carquin
# Processing Record 33 of Set 12 | enterprise
# Processing Record 34 of Set 12 | tobelo
# Processing Record 35 of Set 12 | magadan
# Processing Record 36 of Set 12 | saint croix
# Processing Record 37 of Set 12 | yigo village
# Processing Record 38 of Set 12 | berezovyy
# Processing Record 39 of Set 12 | lubang
# Processing Record 40 of Set 12 | ifakara
# Processing Record 41 of Set 12 | whakatane
# Processing Record 42 of Set 12 | nova sintra
# Processing Record 43 of Set 12 | arroio grande
# Processing Record 44 of Set 12 | marquette
# Processing Record 45 of Set 12 | saint-philippe
# Processing Record 46 of Set 12 | eureka
# Processing Record 47 of Set 12 | korosten'
# City not found. Skipping...
# Processing Record 48 of Set 12 | saint-leu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      3.61        78          62
# 1      blackmans bay -43.0167  147.3167     18.74        53          69
# 2             illizi  26.4833    8.4667     11.89        70          26
# 3     puerto natales -51.7236  -72.4875     12.25        54          40
# 4            klyuchi  52.2667   79.1667    -21.46        87          21
#
#    Wind Speed Country        Date
# 0       10.28      TF  1702248806
# 1        0.45      AU  1702248806
# 2        1.97      DZ  1702248807
# 3        6.69      CL  1702248807
# 4        2.51      RU  1702248807

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      3.61        78          62
# 1            blackmans bay -43.0167  147.3167     18.74        53          69
# 2                   illizi  26.4833    8.4667     11.89        70          26
# 3           puerto natales -51.7236  -72.4875     12.25        54          40
# 4                  klyuchi  52.2667   79.1667    -21.46        87          21
#
#          Wind Speed Country        Date
# City_ID
# 0             10.28      TF  1702248806
# 1              0.45      AU  1702248806
# 2              1.97      DZ  1702248807
# 3              6.69      CL  1702248807
# 4              2.51      RU  1702248807

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='D', facecolors='r', edgecolors='k')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Figa.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='D', grid=True,\
                  facecolors='r', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='D', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='D', grid=True,\
                  facecolors='r', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere, text_coordinates, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           illizi  26.4833   8.4667     11.89        70          26
# 4          klyuchi  52.2667  79.1667    -21.46        87          21
# 5           gardez  33.5974  69.2259     -1.19        36          24
# 7        iowa park  33.9515 -98.6687     11.92        28           0
# 8          colonia  50.9333   6.9500     11.70        79          75
#
#          Wind Speed Country        Date
# City_ID
# 2              1.97      DZ  1702248807
# 4              2.51      RU  1702248807
# 5              0.76      AF  1702248808
# 7              4.12      US  1702248808
# 8              3.60      DE  1702248698

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      3.61        78          62
# 1            blackmans bay -43.0167  147.3167     18.74        53          69
# 3           puerto natales -51.7236  -72.4875     12.25        54          40
# 6              west island -12.1568   96.8225     24.99        83          40
# 9                 waitangi -43.9535 -176.5597     11.49        56           3
#
#          Wind Speed Country        Date
# City_ID
# 0             10.28      TF  1702248806
# 1              0.45      AU  1702248806
# 3              6.69      CL  1702248807
# 6              4.12      CC  1702248808
# 9              2.12      NZ  1702248809

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Northern", (10, 10))
plt.show()

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (-52, 75))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.savefig("../output_data/northern_hem_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
